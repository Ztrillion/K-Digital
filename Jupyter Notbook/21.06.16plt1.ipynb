# %%
# !cd
# Out:
# C:\Users\pc\2021-K-Digital-Training-main\SQL

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# fig, ax = plt.subplots()   nrows, ncols 값은 몇개의 그래프를 생성할지 나타냄

# %%
fig, ax = plt.subplots(nrows=2, ncols=2)
ax[0,0].plot([1, 2, 3, 4], [1, 4, 2, 3])
ax[0,1].plot([1,2,3,4],[2,3,4,1])
ax[1,0].plot([0.2,0.4,0.6,0.8],[0.75,0.55,0.25,1])
ax[1,1].plot([1,1,3,4],[100,200,150,300])
# fig위치 변수 : subplots 전체 컨트롤
fig.suptitle('stock')
# Out:
# Text(0.5, 0.98, 'stock')

# %%
plt.plot([1,2,3,4,5,6], [1, 4, 2.5, 7,4.5,9])

# %%
bb , aa= plt.subplots(nrows=2, ncols=2)  # a figure with a 2x2 grid of Axes

# %%
# 랜덤으로 4row 5column matrix 생성
a = pd.DataFrame(np.random.rand(4, 5), columns = list('abcde'))

# %%
a
# Out:
#           a         b         c         d         e
# 0  0.496831  0.417821  0.013693  0.154334  0.464679
# 1  0.410256  0.336066  0.115020  0.946447  0.549753
# 2  0.658785  0.318332  0.908118  0.323799  0.227132
# 3  0.655375  0.698151  0.560132  0.147495  0.871723

# %%
#pandas를 array로 변경
a_asarray = a.values
a_asarray
# Out:
# array([[0.49683102, 0.41782067, 0.01369284, 0.15433376, 0.46467898],
#        [0.41025552, 0.33606585, 0.11501969, 0.94644681, 0.54975262],
#        [0.65878479, 0.31833222, 0.9081178 , 0.32379895, 0.22713225],
#        [0.65537522, 0.69815126, 0.56013208, 0.14749496, 0.8717234 ]])

# %%
a_asarray.var()
# Out:
# 0.0691150025437231

# %%
b = np.matrix([[1, 2], [3, 4]])
b_asarray = np.asarray(b)

# %%
b_asarray
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
x = np.linspace(0, 2, 100)

# Note that even in the OO-style, we use `.pyplot.figure` to create the figure.
fig, ax = plt.subplots()  # Create a figure and an axes.
#여기서부터 3줄은 선이 어떤값인지 표에 알려준다
ax.plot(x, x, label='smoker')  # Plot some data on the axes.
ax.plot(x, x**2, label='tip')  # Plot more data on the axes...
ax.plot(x, x**3, label='total_bill')  # ... and some more.

# x,y 라벨지정
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.

# 타이틀지정
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend()  # Add a legend.

# %%
x = np.linspace(0, 2, 100)

plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend()
